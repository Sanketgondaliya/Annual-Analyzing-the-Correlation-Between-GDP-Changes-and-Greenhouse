# %%
# import the require libraries
import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **GDP by sector**

# %%
df = pd.read_csv('/content/drive/MyDrive/DATA/gdp by sector.csv')

# %%
df.columns
# Out:
# Index(['Year', 'Agriculture(%)', 'Industry(%)', 'Services(%)', 'Unnamed: 4'], dtype='object')

# %%
df.drop('Unnamed: 4', axis=1)
# Out:
#     Year  Agriculture(%)  Industry(%)  Services(%)
# 0   2012           16.85        29.40        46.30
# 1   2013           17.15        28.40        46.70
# 2   2014           16.79        27.66        47.82
# 3   2015           16.17        27.35        47.78
# 4   2016           16.36        26.62        47.75
# 5   2017           16.56        26.50        47.67
# 6   2018           16.03        26.41        48.43
# 7   2019           16.76        24.59        50.08
# 8   2020           18.64        25.02        48.07
# 9   2021           17.33        26.07        47.94
# 10  2022           16.73        25.66        48.44

# %%
# Get unique years for dropdown options
years_options = [{'label': str(year), 'value': year} for year in df['Year']]

# Default selected year
selected_year = df['Year'].max()

# Create pie charts for each year
figs = []
for year in df['Year']:
    filtered_df = df[df['Year'] == year]

    fig = px.pie(filtered_df,
                 values=filtered_df.iloc[:, 1:].values.flatten(),
                 names=filtered_df.iloc[:, 1:].columns.tolist()*len(filtered_df),
                 title=f'Distribution of GDP by Sector in {year}',
                 template='plotly_dark',
                 hole=0.3,
                )

    fig.update_layout(
        height=600,
        showlegend=False
    )

    figs.append(fig)

# Display the app
for i, year in enumerate(df['Year']):
    figs[i].show()

# %%
# Get unique years for dropdown options
years_options = [{'label': str(year), 'value': year} for year in df['Year']]

selected_year = int(input("Enter the year (2012-2022): "))

# Create pie chart for the selected year
filtered_df = df[df['Year'] == selected_year]

fig = px.pie(filtered_df,
             values=filtered_df.iloc[:, 1:].values.flatten(),
             names=filtered_df.iloc[:, 1:].columns.tolist(),
             title=f'Distribution of GDP by Sector in {selected_year}',
             template='plotly_dark',
             hole=0.3,
            )

fig.update_layout(
    height=600
)

# Show the pie chart
fig.show()
# Out:
# Enter the year (2012-2022): 2022
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d8d32c8e-eaaa-4cbf-9ae5-4c1021897a0a" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8d32c8e-eaaa-4cbf-9ae5-4c1021897a0a")) {                    Plotly.newPlot(                        "d8d32c8e-eaaa-4cbf-9ae5-4c1021897a0a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Agriculture(%)","Industry(%)","Services(%)","Unnamed: 4"],"legendgroup":"","name":"","showlegend":true,"values":[16.73,25.66,48.44,null],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ti ...

# %% [markdown]
# # **Year-on-year change in GDP**

# %%
gdp_year = pd.read_csv('/content/drive/MyDrive/DATA/real-gdp-growth.csv')

# %%
gdp_year
# Out:
#            Entity  Year  \
# 0     Afghanistan  2021
# 1     Afghanistan  2020
# 2     Afghanistan  2019
# 3     Afghanistan  2018
# 4     Afghanistan  2017
# ...           ...   ...
# 2713     Zimbabwe  2014
# 2714     Zimbabwe  2013
# 2715     Zimbabwe  2012
# 2716     Zimbabwe  2011
# 2717     Zimbabwe  2010
#
#       Gross domestic product, constant prices - Percent change - Observations
# 0                                               -20.737
# 1                                                -2.351
# 2                                                 3.912
# 3                                                 1.189
# 4                                                 2.647
# ...                                                 ...
# 2713                                              2.394
# 2714                                              1.975
# 2715                                             16.658
# 2716                                             14.197
# 2717                                             19.683
#
# [2718 rows x 3 columns]

# %%
gdp_year.columns
# Out:
# Index(['Entity', 'Year',
#        'Gross domestic product, constant prices - Percent change - Observations'],
#       dtype='object')

# %%
gdp_year['Gross domestic product, constant prices - Percent change - Observations'].tolist()

# %%
selected_country = 'India'
country_data = gdp_year[gdp_year['Entity'] == selected_country]

# Create a line chart
fig = px.line(country_data, x='Year', y='Gross domestic product, constant prices - Percent change - Observations',
              title=f'GDP Growth Rate Over Years - {selected_country}',
              labels={'Gross domestic product, constant prices - Percent change - Observations': 'GDP Growth Rate (%)'},
              template='plotly_dark')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7d3bf57e-2731-4faa-acb8-e8c059abf973" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d3bf57e-2731-4faa-acb8-e8c059abf973")) {                    Plotly.newPlot(                        "7d3bf57e-2731-4faa-acb8-e8c059abf973",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eGDP Growth Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2023,2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010],"xaxis":"x","y":[6.332,7.24,9.05,-5.831,3.871,6.454,6.795,8.256,7.996,7.41,6.386,5.456,6.638,10.26],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"} ...

# %%
selected_country = 'India'
country_data = gdp_year[gdp_year['Entity'] == selected_country]

# Create a line chart
fig = px.line(country_data, x='Year', y='Gross domestic product, constant prices - Percent change - Observations',
              title=f'GDP Growth Rate Over Years - {selected_country}',
              labels={'Gross domestic product, constant prices - Percent change - Observations': 'GDP Growth Rate (%)'},
              template='plotly_dark')

# Customize layout to play chart year wise
fig.update_layout(
    xaxis=dict(type='category'),
    updatemenus=[
        {
            'buttons': [
                {
                    'args': [None, {'frame': {'duration': 500, 'redraw': True}, 'fromcurrent': True}],
                    'label': 'Play',
                    'method': 'animate'
                },
                {
                    'args': [[None], {'frame': {'duration': 0, 'redraw': True}, 'mode': 'immediate', 'transition': {'duration': 0}}],
                    'label': 'Pause',
                    'method': 'animate'
                }
            ],
            'direction': 'left',
            'pad': {'r': 10, 't': 87},
            'showactive': False,
            'type': 'buttons',
            'x': 0.1,
            'xanchor': 'right',
            'y': 0,
            'yanchor': 'top'
        }
    ],
    sliders=[{
        'active': 0,
        'yanchor': 'top',
        'xanchor': 'left',
        'currentvalue': {
            'font': {'size': 20},
            'prefix': 'Year:',
            'visible': True,
            'xanchor': 'right'
        },
        'transition': {'duration': 300, 'easing': 'cubic-in-out'},
        'pad': {'b': 10, 't': 50},
        'len': 0.9,
        'x': 0.1,
        'y': 0
    }]
)

# Define frames for animation
frames = [dict(data=[dict(type='scatter', x=country_data['Year'][:i+1],
                          y=country_data['Gross domestic product, constant prices - Percent change - Observations'][:i+1])],
               traces=[0],
               name=f'Frame {i+1}')
          for i in range(len(country_data))]

fig.frames = frames

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2ac3559c-720c-4acf-a02d-00961536469e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ac3559c-720c-4acf-a02d-00961536469e")) {                    Plotly.newPlot(                        "2ac3559c-720c-4acf-a02d-00961536469e",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eGDP Growth Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2023,2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010],"xaxis":"x","y":[6.332,7.24,9.05,-5.831,3.871,6.454,6.795,8.256,7.996,7.41,6.386,5.456,6.638,10.26],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"} ...

# %% [markdown]
# # **Greenhouse gas emissions by sector**

# %%
Greenhouse_gas_emissions_by_sector = pd.read_csv('/content/drive/MyDrive/DATA/ghg-emissions-by-sector.csv')

# %%
Greenhouse_gas_emissions_by_sector
# Out:
#            Entity  Year  Greenhouse gas emissions from agriculture  \
# 0     Afghanistan  2020                               1.515000e+07
# 1          Africa  2020                               1.051410e+09
# 2         Albania  2020                               2.590000e+06
# 3         Algeria  2020                               1.262000e+07
# 4         Andorra  2020                               0.000000e+00
# ...           ...   ...                                        ...
# 2250      Vietnam  2010                               6.774000e+07
# 2251        World  2010                               5.493460e+09
# 2252        Yemen  2010                               7.770000e+06
# 2253       Zambia  2010                               2.211000e+07
# 2254     Zimbabwe  2010                               1.287000e+07
#
#       Greenhouse gas emissions from land use change and forestry  \
# 0                                          1.500000e+05
# 1                                          1.364420e+09
# 2                                         -2.500000e+05
# 3                                          3.000000e+05
# 4                                          0.000000e+00
# ...                                                 ...
# 2250                                       1.826000e+07
# 2251                                       1.637730e+09
# 2252                                       0.000000e+00
# 2253                                       4.121000e+07
# 2254                                       1.122000e+07
#
#       Greenhouse gas emissions from waste  \
# 0                            3.700000e+06
# 1                            1.905100e+08
# 2                            9.900000e+05
# 3                            1.501000e+07
# 4                            6.000000e+04
# ...                                   ...
# 2250                         1.778000e+07
# 2251                         1.465130e+09
# 2252                         2.220000e+06
# 2253                         2.780000e+06
# 2254                         2.200000e+06
#
#       Greenhouse gas emissions from buildings  \
# 0                                2.360000e+06
# 1                                1.822700e+08
# 2                                5.100000e+05
# 3                                2.694000e+07
# 4                                         NaN
# ...                                       ...
# 2250                             1.534000e+07
# 2251                             2.993850e+09
# 2252                             3.320000e+06
# 2253                             1.470000e+06
# 2254                             2.670000e+06
#
#       Greenhouse gas emissions from industry  \
# 0                               1.380000e+06
# 1                               2.336900e+08
# 2                               1.200000e+06
# 3                               1.773000e+07
# 4                               7.000000e+04
# ...                                      ...
# 2250                            2.572000e+07
# 2251                            2.228910e+09
# 2252                            9.000000e+05
# 2253                            6.800000e+05
# 2254                            1.110000e+06
#
#       Greenhouse gas emissions from manufacturing and construction  \
# 0                                          2.860000e+06
# 1                                          1.477400e+08
# 2                                          9.900000e+05
# 3                                          1.331000e+07
# 4                                                   NaN
# ...                                                 ...
# 2250                                       4.204000e+07
# 2251                                       6.123010e+09
# 2252                                       3.040000e+06
# 2253                                       8.000000e+05
# 2254                                       1.230000e+06
#
#       Greenhouse gas emissions from transport  \
# 0                                3.260000e+06
# 1                                3.428400e+08
# 2                                1.590000e+06
# 3                                4.137000e+07
# 4                                         NaN
# ...                                       ...
# 2250                             3.182000e+07
# 2251                             7.185970e+09
# 2252                             7.350000e+06
# 2253                             1.270000e+06
# 2254                             1.360000e+06
#
#       Greenhouse gas emissions from electricity and heat  \
# 0                                          1.700000e+05
# 1                                          5.517600e+08
# 2                                          1.300000e+05
# 3                                          4.920000e+07
# 4                                                   NaN
# ...                                                 ...
# 2250                                       4.163000e+07
# 2251                                       1.422097e+10
# 2252                                       8.120000e+06
# 2253                                       6.000000e+04
# 2254                                       4.930000e+06
#
#       Fugitive emissions of greenhouse gases from energy production  \
# 0                                          2.240000e+06
# 1                                          3.043200e+08
# 2                                          0.000000e+00
# 3                                          8.574000e+07
# 4                                          0.000000e+00
# ...                                                 ...
# 2250                                       1.353000e+07
# 2251                                       3.098340e+09
# 2252                                       1.457000e+07
# 2253                                       0.000000e+00
# 2254                                       3.800000e+05
#
#       Greenhouse gas emissions from other fuel combustion  \
# 0                                              110000.0
# 1                                            26050000.0
# 2                                              300000.0
# 3                                             4780000.0
# 4                                                   NaN
# ...                                                 ...
# 2250                                          1660000.0
# 2251                                        633250000.0
# 2252                                           810000.0
# 2253                                           120000.0
# 2254                                          1480000.0
#
#       Greenhouse gas emissions from bunker fuels
# 0                                   2.000000e+04
# 1                                   3.157000e+07
# 2                                   1.500000e+05
# 3                                   9.700000e+05
# 4                                            NaN
# ...                                          ...
# 2250                                2.550000e+06
# 2251                                1.132180e+09
# 2252                                9.000000e+05
# 2253                                9.000000e+04
# 2254                                3.000000e+04
#
# [2255 rows x 13 columns]

# %%
Greenhouse_gas_emissions_by_sector.columns
# Out:
# Index(['Entity', 'Year', 'Greenhouse gas emissions from agriculture',
#        'Greenhouse gas emissions from land use change and forestry',
#        'Greenhouse gas emissions from waste',
#        'Greenhouse gas emissions from buildings',
#        'Greenhouse gas emissions from industry',
#        'Greenhouse gas emissions from manufacturing and construction',
#        'Greenhouse gas emissions from transport',
#        'Greenhouse gas emissions from electricity and heat',
#        'Fugitive emissions of greenhouse gases from energy production',
#        'Greenhouse gas emissions from other fuel combustion',
#        'Greenhouse gas emissions from bunker fuels'],
#       dtype='object')

# %%
Greenhouse_gas_emissions_by_sector['Entity'].tolist()

# %%
# Melt the data for easier plotting
df_melted = pd.melt(Greenhouse_gas_emissions_by_sector, id_vars=['Entity', 'Year'], var_name='Sector', value_name='Emissions')

# User input for entity and year
selected_entity = input("Enter the entity: ")
selected_year = input("Enter the year: ")

# Filter the data based on user input
filtered_data = df_melted[(df_melted['Entity'] == selected_entity) & (df_melted['Year'] == int(selected_year))]

# Check if the filtered data is empty
if filtered_data.empty:
    print(f"No data available for {selected_entity} in {selected_year}. Please check your input.")
else:
    # Create a pie chart
    fig = px.pie(filtered_data, names='Sector', values='Emissions',
                 title=f'Greenhouse Gas Emissions by Sector in {selected_entity}',
                 hover_data=['Emissions'])

    # Set the background color
    fig.update_layout({
        'plot_bgcolor': 'rgba(0, 0, 0, 0)',
        'paper_bgcolor': 'rgba(0, 0, 0, 0)',
        'font_color': 'white',

    })

    fig.show()
# Out:
# Enter the entity: India
# Enter the year: 2020
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="53ab433a-ea22-42bb-946f-5c09153a9389" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53ab433a-ea22-42bb-946f-5c09153a9389")) {                    Plotly.newPlot(                        "53ab433a-ea22-42bb-946f-5c09153a9389",                        [{"customdata":[[741920000.0],[-33870000.0],[85350000.0],[162490000.0],[149370000.0],[509450020.0],[276440000.0],[1121980000.0],[88990000.0],[64830000.0],[8920000.0]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Sector=%{label}\u003cbr\u003eEmissions=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Greenhouse gas emissions from agriculture","Greenhouse gas emissions from land use change and forestry","Greenhouse gas emissions from waste","Greenhouse gas emissions from buildings","Greenhouse gas emissions from industry","Greenhouse gas emissions from manufacturing and construction","Greenhouse gas emissions from transport","Greenhouse gas emissions from electricity and heat","Fugitive emissions of greenhouse gases from energy production","Greenhouse gas emissions from other fuel combustion","Greenhouse gas emissions from bunker fuels"],"legendgroup":"","name":"","showlegend":true,"values":[741920000.0,-33870000.0,85350000.0,162490000.0,149370000.0,509450020.0,276440000.0,1121980000.0,88990000.0,64830000.0,8920000.0],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953" ...

# %% [markdown]
# ### **Year-on-year change in Greenhouse gas emissions**

# %%
Year_on_year_change_in_Greenhouse_gas_emissions = pd.read_csv('/content/drive/MyDrive/DATA/absolute-change-ghg.csv')

# %%
Year_on_year_change_in_Greenhouse_gas_emissions
# Out:
#             Entity    Year  Annual CO₂ emissions growth (abs)
# 0      Afghanistan  2022.0                          -135200.0
# 1           Africa  2022.0                        -18587520.0
# 2          Albania  2022.0                            51078.0
# 3          Algeria  2022.0                         -3880064.0
# 4          Andorra  2022.0                             5599.0
# ...            ...     ...                                ...
# 28152          NaN     NaN                                NaN
# 28153          NaN     NaN                                NaN
# 28154          NaN     NaN                                NaN
# 28155          NaN     NaN                                NaN
# 28156          NaN     NaN                                NaN
#
# [28157 rows x 3 columns]

# %%
Year_on_year_change_in_Greenhouse_gas_emissions.columns
# Out:
# Index(['Entity', 'Year', 'Annual CO₂ emissions growth (abs)'], dtype='object')

# %%
Year_on_year_change_in_Greenhouse_gas_emissions['Annual CO₂ emissions growth (abs)'].tolist()

# %%
Year_on_year_change_in_Greenhouse_gas_emissions['Entity'].tolist()

# %%
selected_country = 'India'
country_data = Year_on_year_change_in_Greenhouse_gas_emissions[Year_on_year_change_in_Greenhouse_gas_emissions['Entity'] == selected_country]

# Create a line chart
fig = px.line(country_data, x='Year', y='Annual CO₂ emissions growth (abs)',
              title=f'Year-on-year change in Greenhouse gas emissions - {selected_country}',
              labels={'CO₂ emissions': 'Annual CO₂ emissions growth (abs)'},
              template='plotly_dark',
              line_shape='linear',  # Change line shape to linear (default is 'linear')
              markers=True,         # Show data points as markers
              line_dash_sequence=['solid'],  # Set line dash style
              )
# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8432b343-39f9-47ba-9eda-33ae5780c6a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8432b343-39f9-47ba-9eda-33ae5780c6a1")) {                    Plotly.newPlot(                        "8432b343-39f9-47ba-9eda-33ae5780c6a1",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eAnnual CO\u2082 emissions growth (abs)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[2022.0,2021.0,2020.0,2019.0,2018.0,2017.0,2016.0,2015.0,2014.0,2013.0,2012.0,2011.0,2010.0],"xaxis":"x","y":[155422460.0,252669700.0,-191335940.0,19830272.0,166450940.0,71948800.0,120438530.0,85875710.0,153245700.0,69398400.0,160987260.0,87375230.0,65120896.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorba ...

# %%
selected_country = 'India'
country_data = Year_on_year_change_in_Greenhouse_gas_emissions[Year_on_year_change_in_Greenhouse_gas_emissions['Entity'] == selected_country]

# Sort the data by year in ascending order
country_data = country_data.sort_values(by='Year')

# Create a line chart
fig = px.line(country_data, x='Year', y='Annual CO₂ emissions growth (abs)',
              title=f'Year-on-year change in Greenhouse gas emissions - {selected_country}',
              labels={'Annual CO₂ emissions growth (abs)': 'Annual CO₂ emissions growth (abs)'},
              template='plotly_dark',
              line_shape='linear',  # Change line shape to linear (default is 'linear')
              markers=True,         # Show data points as markers
              line_dash_sequence=['solid']  # Set line dash style
              )

# Customize layout to play chart year-wise
fig.update_layout(
    xaxis=dict(type='category'),
    updatemenus=[
        {
            'buttons': [
                {
                    'args': [None, {'frame': {'duration': 500, 'redraw': True}, 'fromcurrent': True}],
                    'label': 'Play',
                    'method': 'animate'
                },
                {
                    'args': [[None], {'frame': {'duration': 0, 'redraw': True}, 'mode': 'immediate', 'transition': {'duration': 0}}],
                    'label': 'Pause',
                    'method': 'animate'
                }
            ],
            'direction': 'left',
            'pad': {'r': 10, 't': 87},
            'showactive': False,
            'type': 'buttons',
            'x': 0.1,
            'xanchor': 'right',
            'y': 0,
            'yanchor': 'top'
        }
    ],
    sliders=[{
        'active': 0,
        'yanchor': 'top',
        'xanchor': 'left',
        'currentvalue': {
            'font': {'size': 20},
            'prefix': 'Year:',
            'visible': True,
            'xanchor': 'right'
        },
        'transition': {'duration': 300, 'easing': 'cubic-in-out'},
        'pad': {'b': 10, 't': 50},
        'len': 0.9,
        'x': 0.1,
        'y': 0
    }]
)

# Define frames for animation
frames = [dict(data=[dict(type='scatter', x=country_data['Year'][:i+1],
                          y=country_data['Annual CO₂ emissions growth (abs)'][:i+1])],
               traces=[0],
               name=f'Frame {i+1}')
          for i in range(len(country_data))]

fig.frames = frames

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d6fc1e8c-f3f1-493d-a2e5-ee78f183346f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6fc1e8c-f3f1-493d-a2e5-ee78f183346f")) {                    Plotly.newPlot(                        "d6fc1e8c-f3f1-493d-a2e5-ee78f183346f",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eAnnual CO\u2082 emissions growth (abs)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2010.0,2011.0,2012.0,2013.0,2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0],"xaxis":"x","y":[65120896.0,87375230.0,160987260.0,69398400.0,153245700.0,85875710.0,120438530.0,71948800.0,166450940.0,19830272.0,-191335940.0,252669700.0,155422460.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorba ...

# %% [markdown]
# # **Annual change in GDP and Greenhouse gas emissions**

# %%
Annual_change_in_GDP_and_Greenhouse_gas_emissions = pd.read_csv('/content/drive/MyDrive/DATA/ghg-gdp-growth.csv')

# %%
Annual_change_in_GDP_and_Greenhouse_gas_emissions
# Out:
#            Entity  Year  GDP growth (annual %)  \
# 0     Afghanistan  2022                    NaN
# 1     Afghanistan  2021             -20.737146
# 2     Afghanistan  2020              -2.351101
# 3     Afghanistan  2019               3.911604
# 4     Afghanistan  2018               1.189228
# ...           ...   ...                    ...
# 3222     Zimbabwe  2014               1.484543
# 3223     Zimbabwe  2013               3.196731
# 3224     Zimbabwe  2012              15.744877
# 3225     Zimbabwe  2011              14.620207
# 3226     Zimbabwe  2010              21.452060
#
#       Annual CO₂ emissions growth (%)
# 0                           -1.100695
# 1                            3.323352
# 2                            7.277322
# 3                            2.436423
# 4                            9.627903
# ...                               ...
# 3222                         2.354252
# 3223                         3.710806
# 3224                         8.593583
# 3225                        18.382275
# 3226                         6.112206
#
# [3227 rows x 4 columns]

# %%
Annual_change_in_GDP_and_Greenhouse_gas_emissions.columns
# Out:
# Index(['Entity', 'Year', 'GDP growth (annual %)',
#        'Annual CO₂ emissions growth (%)'],
#       dtype='object')

# %%
Annual_change_in_GDP_and_Greenhouse_gas_emissions = Annual_change_in_GDP_and_Greenhouse_gas_emissions.rename(columns={'Annual CO₂ emissions growth (%)':'Annual Greenhouse gas emissions growth (%)'})

# %%
selected_country = 'India'
country_data = Annual_change_in_GDP_and_Greenhouse_gas_emissions[Annual_change_in_GDP_and_Greenhouse_gas_emissions['Entity'] == selected_country]

# Create a line chart
fig = px.line(country_data, x='Year', y=['GDP growth (annual %)', 'Annual Greenhouse gas emissions growth (%)'],
              title=f'Year-wise GDP Growth and Greenhouse gas  Emissions Growth - {selected_country}',
              labels={'value': 'Percentage'},
              template='plotly_dark',
              line_shape='linear',  # Change line shape to linear (default is 'linear')
              markers=True,         # Show data points as markers
              line_dash_sequence=['solid'],  # Set line dash style
              )

# Customize layout
fig.update_layout(
    xaxis=dict(type='category'),
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8ae82b6d-e6c0-4302-a290-10a376e0f6e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ae82b6d-e6c0-4302-a290-10a376e0f6e1")) {                    Plotly.newPlot(                        "8ae82b6d-e6c0-4302-a290-10a376e0f6e1",                        [{"hovertemplate":"variable=GDP growth (annual %)\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GDP growth (annual %)","line":{"color":"#636efa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"GDP growth (annual %)","orientation":"v","showlegend":true,"x":[2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010],"xaxis":"x","y":[null,8.681229,-6.5960803,3.7379186,6.453851,6.7953835,8.256306,7.996254,7.410228,6.3861065,5.456389,5.241315,8.497584],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Annual CO\u2082 emissions growth (%)\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Annual CO\u2082 emissions growth (%)","line":{"color":"#EF553B","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Annual CO\u2082 emissions growth (%)","orientation":"v","showlegend":true,"x":[2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010],"xaxis":"x","y":[5.811882,10.434198,-7.3227763,0.7647395,6.85941,3.0555964,5.390632,3.997302,7.6811075,3.603804,9.122574,5.20916,4.039216],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b ...

# %%
selected_country = 'India'
country_data = Annual_change_in_GDP_and_Greenhouse_gas_emissions[Annual_change_in_GDP_and_Greenhouse_gas_emissions['Entity'] == selected_country]

# Create a line chart
fig = px.line(country_data, x='Year', y=['GDP growth (annual %)', 'Annual Greenhouse gas emissions growth (%)'],
              title=f'Year-wise GDP Growth and Annual Greenhouse gas emissions growth (%) Emissions Growth - {selected_country}',
              labels={'value': 'Percentage'},
              template='plotly_dark',
              line_shape='linear',
              markers=True,
              line_dash_sequence=['solid']
              )

# Customize layout to play chart year-wise
fig.update_layout(
    xaxis=dict(type='category'),
    updatemenus=[
        {
            'buttons': [
                {
                    'args': [None, {'frame': {'duration': 500, 'redraw': True}, 'fromcurrent': True}],
                    'label': 'Play',
                    'method': 'animate'
                },
                {
                    'args': [[None], {'frame': {'duration': 0, 'redraw': True}, 'mode': 'immediate', 'transition': {'duration': 0}}],
                    'label': 'Pause',
                    'method': 'animate'
                }
            ],
            'direction': 'left',
            'pad': {'r': 10, 't': 87},
            'showactive': False,
            'type': 'buttons',
            'x': 0.1,
            'xanchor': 'right',
            'y': 0,
            'yanchor': 'top'
        }
    ],
    sliders=[{
        'active': 0,
        'yanchor': 'top',
        'xanchor': 'left',
        'currentvalue': {
            'font': {'size': 20},
            'prefix': 'Year:',
            'visible': True,
            'xanchor': 'right'
        },
        'transition': {'duration': 300, 'easing': 'cubic-in-out'},
        'pad': {'b': 10, 't': 50},
        'len': 0.9,
        'x': 0.1,
        'y': 0,
        'name': 'Year Slider'  # Add a name for the slider
    }]
)

# Define frames for animation
frames = [dict(data=[
                    dict(type='scatter', x=country_data['Year'][:i+1], y=country_data['GDP growth (annual %)'][:i+1], name='GDP growth'),
                    dict(type='scatter', x=country_data['Year'][:i+1], y=country_data['Annual Greenhouse gas emissions growth (%)'][:i+1], name='Greenhouse gas emissions growth')
                   ],
               name=f'Frame {i+1}')
          for i in range(len(country_data))]

fig.frames = frames

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="38b59000-2dd7-49af-9e15-5869a47fc7d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38b59000-2dd7-49af-9e15-5869a47fc7d7")) {                    Plotly.newPlot(                        "38b59000-2dd7-49af-9e15-5869a47fc7d7",                        [{"hovertemplate":"variable=GDP growth (annual %)\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GDP growth (annual %)","line":{"color":"#636efa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"GDP growth (annual %)","orientation":"v","showlegend":true,"x":[2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010],"xaxis":"x","y":[null,8.681229,-6.5960803,3.7379186,6.453851,6.7953835,8.256306,7.996254,7.410228,6.3861065,5.456389,5.241315,8.497584],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Annual Greenhouse gas emissions growth (%)\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Annual Greenhouse gas emissions growth (%)","line":{"color":"#EF553B","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Annual Greenhouse gas emissions growth (%)","orientation":"v","showlegend":true,"x":[2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010],"xaxis":"x","y":[5.811882,10.434198,-7.3227763,0.7647395,6.85941,3.0555964,5.390632,3.997302,7.6811075,3.603804,9.122574,5.20916,4.039216],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555 ...
